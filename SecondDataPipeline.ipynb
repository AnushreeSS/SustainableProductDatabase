# %% [markdown]
# ## Second Data Pipeline
# In this, the keyword extractor from the main pipline is reused on a different dataset

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read Product Data

# %%
# This dataset is not provided in the repository (replace the URL with your data)
file_path = "amazon_aspect_labeled_products.tsv" 
labelled_data = pd.read_csv(file_path)
labelled_data.drop(labelled_data.columns[0], axis=1, inplace=True)
labelled_data = labelled_data[["asin", "description", "title",]]
labelled_data
# Out:
#             asin                                        description  \
# 0     B000B5H26O  ['Yorkshire Tea never compromise on the qualit...
# 1     B000F3WS7K  ['We choose teas from our three favorite origi...
# 2     B000HRS7OM  ['Made with a blend of teas from Assam, Africa...
# 3     B001E5DXY0  ['We choose teas from our three favorite origi...
# 4     B004G90QE6  ['Made with a blend of teas from Assam, Africa...
# ...          ...                                                ...
# 9043  B01CMYK8W6  ['What happens over the course of 18 months? W...
# 9044  B01DJXXR4U  ['Four simple, natural ingredients including o...
# 9045  B01FIV3SG8  ['Tillamook Medium Cheddar Thick Sliced Cheese...
# 9046  B01FJFO2S6  ['Tillamook Country Smoker Big Dad beef sticks...
# 9047  B00BPAP4MI  ['Zaytoun', 'Statements regarding dietary supp...
#
#                                                   title
# 0     Taylors of Harrogate Yorkshire Gold Tea, 160 T...
# 1     Taylors of Harrogate Yorkshire Gold, 40 Teabag...
# 2       Taylors of Harrogate Yorkshire Red, 160 Teabags
# 3     Taylors of Harrogate Yorkshire Gold Loose Leaf...
# 4       Taylors of Harrogate Yorkshire Red, 240 Teabags
# ...                                                 ...
# 9043  Tillamook Extra Sharp White Cheddar Cheese Age...
# 9044  Tillamook Special Reserve Extra Sharp Cheddar ...
# 9045  Tillamook Medium Cheddar Thick Sliced Cheese 1...
# 9046  Tillamook Country Smoker Big Dad Beef Stick 20...
# 9047  Zaytoun Organic Palestinian Couscous 250 g (Pa...
#
# [9048 rows x 3 columns]

# %% [markdown]
# ### Data Pre-Processing

# %%
import import_ipynb
from ProjectModules import ColumnDropper, RowDropper, StringCleaner
from sklearn.pipeline import Pipeline
# Out:
# importing Jupyter notebook from ProjectModules.ipynb

# %%
print(f"Number of columns: {labelled_data.shape[1]} | Number of records= {labelled_data.shape[0]}")
print(f"Columns in labelled amazon dataset: {list(labelled_data.columns)}")
# Out:
# Number of columns: 3 | Number of records= 9048
# Columns in labelled amazon dataset: ['asin', 'description', 'title']

# %%
labelled_data["clean_description"] = labelled_data["description"]
labelled_data_preprocess_pipeline = Pipeline([
    ("clean_string", StringCleaner(columns=['clean_description'])),
    ("drop_rows", RowDropper(columns=['clean_description']))
])
labelled_data = labelled_data_preprocess_pipeline.fit_transform(labelled_data)
print(f"Number of columns: {labelled_data.shape[1]} | Number of records= {labelled_data.shape[0]}")
print(f"Columns in amazon dataset: {list(labelled_data.columns)}")
labelled_data.head(2)
# Out:
# Number of columns: 4 | Number of records= 7963
# Columns in amazon dataset: ['asin', 'description', 'title', 'clean_description']
#          asin                                        description  \
# 0  B000F3WS7K  ['We choose teas from our three favorite origi...
# 1  B000HRS7OM  ['Made with a blend of teas from Assam, Africa...
#
#                                                title  \
# 0  Taylors of Harrogate Yorkshire Gold, 40 Teabag...
# 1    Taylors of Harrogate Yorkshire Red, 160 Teabags
#
#                                    clean_description
# 0  we choose teas from our three favorite origins...
# 1  made with a blend of teas from assam africa an...

# %% [markdown]
# ### Keyword Extraction

# %%
import pickle

# %%
# Load existing keyword extractor and use it is compute TF-IDF scores
keyword_extractor = pickle.load(open("keyword_extractor", "rb"))
product_tfidf = keyword_extractor.compute_tfidf(labelled_data["clean_description"])
product_tfidf = keyword_extractor.eliminate_redundant_bigram()

# %% [markdown]
# ### Keyword Mapper

# %%
keyword_mapper = pickle.load(open('keyword_mapper', 'rb'))
keyword_mapper.product_tfidf = keyword_extractor.product_tfidf
keyword_mapper.onto_tfidf = keyword_extractor.ontology_tf
keyword_mapper.map_keywords()
# Out:
#        product_idx  onto_idx  imp_score
# 0                0       180        1.0
# 1                7        84        1.0
# 2                7        83        1.0
# 3                7        82        1.0
# 4                7        81        1.0
# ...            ...       ...        ...
# 15337         7944       240        1.0
# 15338         7944       239        1.0
# 15339         7944       238        1.0
# 15340         7944       237        1.0
# 15341         7959       182        0.5
#
# [15342 rows x 3 columns]

# %% [markdown]
# ### Integrate and Aggregate Data

# %%
keyword_mapper.integrate_ontology(keyword_mapper.ontology_data)
# Out:
#        product_idx  onto_idx  imp_score                        tag  \
# 0                0       180        1.0        high in antioxidant
# 1                7        84        1.0               contain milk
# 2                7        83        1.0               contain milk
# 3                7        82        1.0               contain milk
# 4                7        81        1.0               contain milk
# ...            ...       ...        ...                        ...
# 15337         7944       240        1.0                    no milk
# 15338         7944       239        1.0                    no milk
# 15339         7944       238        1.0                    no milk
# 15340         7944       237        1.0                    no milk
# 15341         7959       182        0.5  high quality and standard
#
#                                               preference preference category  \
# 0                          Products rich in antioxidants              Health
# 1                                         Vegan products              Health
# 2      Products from companies that support animal ri...              Social
# 3                                  Lactose-free products              Health
# 4                                 Allergen-free products              Health
# ...                                                  ...                 ...
# 15337                                     Vegan products              Health
# 15338  Products from companies that support animal ri...              Social
# 15339                              Lactose-free products              Health
# 15340                             Allergen-free products              Health
# 15341   Award winning or high quality certified products             Quality
#
#        association  conditional  association_imp_score
# 0                1        False                    1.0
# 1               -1         True                   -1.0
# 2               -1        False                   -1.0
# 3               -1         True                   -1.0
# 4               -1         True                   -1.0
# ...            ...          ...                    ...
# 15337            1         True                    1.0
# 15338            1        False                    1.0
# 15339            1         True                    1.0
# 15340            1         True                    1.0
# 15341            1        False                    0.5
#
# [15342 rows x 9 columns]

# %%
final_mapping = keyword_mapper.aggregate_mapping(by="preference category", conditional=False)
final_mapping.columns = [i[1] for i in final_mapping.columns]
final_mapping
# Out:
#              Environment    Health   Quality    Social
# product_idx
# 0                    NaN  1.000000       NaN       NaN
# 7                    NaN       NaN       NaN -1.000000
# 14                   NaN  1.000000       NaN       NaN
# 21                   NaN  0.185802       NaN -0.395994
# 23              0.800763  0.800763       NaN  0.334182
# ...                  ...       ...       ...       ...
# 7918                 NaN  0.794614  0.303557       NaN
# 7927                 NaN  0.563403       NaN       NaN
# 7928                 NaN       NaN       NaN -1.000000
# 7944                 NaN       NaN       NaN  1.000000
# 7959                 NaN       NaN  0.500000       NaN
#
# [3018 rows x 4 columns]

# %%
final_mapping[final_mapping.count(axis=1)>1].head(15)
# Out:
#              Environment    Health   Quality    Social
# product_idx
# 21                   NaN  0.185802       NaN -0.395994
# 23              0.800763  0.800763       NaN  0.334182
# 24              0.204943  0.340762  0.122738       NaN
# 26              0.480286  0.447936       NaN  0.267137
# 27              0.441434  0.441434       NaN  0.441434
# 28              0.441434  0.441434       NaN  0.441434
# 30              0.170049  0.211354  0.087571  0.295493
# 34              0.170049  0.211354  0.087571  0.295493
# 35              0.441434  0.441434       NaN  0.441434
# 37              0.539677  0.503326       NaN  0.503326
# 38              0.539677  0.503326       NaN  0.503326
# 40              0.303179  0.251063       NaN  0.173510
# 41              0.800763  0.800763       NaN  0.334182
# 42                   NaN  0.500000       NaN  0.316228
# 44              0.800763  0.800763       NaN  0.334182

# %%
supplementary_info = keyword_mapper.aggregate_mapping(by="preference", conditional=True)
supplementary_info.columns = [i[1] for i in supplementary_info.columns]

supplementary_info.head(5)
# Out:
#              Allergen-free products  Gluten-free products  \
# product_idx
# 7                         -1.000000                   NaN
# 18                              NaN              1.000000
# 21                        -0.295215                   NaN
# 23                        -0.598981              0.800763
# 26                        -0.456056              0.400109
#
#              Lactose-free products  Vegan products  Vegetarian products
# product_idx
# 7                        -1.000000       -1.000000                  NaN
# 18                             NaN             NaN                  NaN
# 21                             NaN       -0.395994            -0.293779
# 23                        0.800763       -0.699872             0.800763
# 26                        0.609690       -0.450642             0.447936

# %%
vocabulary = pd.DataFrame()
vocabulary["keywords"] = keyword_extractor.get_vocab()
keywords = product_tfidf.tocsr().nonzero()
product_keywords = pd.DataFrame()
product_keywords["product_idx"]=keywords[0]
product_keywords["vocab_idx"]=keywords[1]
labelled_data = labelled_data.merge(product_keywords.merge(vocabulary, 
                                           left_on="vocab_idx", 
                                           right_index=True, 
                                           how="left").groupby(by="product_idx").agg({'keywords':', '.join}), left_index=True, right_index=True, how="left")
labelled_data
# Out:
#             asin                                        description  \
# 0     B000F3WS7K  ['We choose teas from our three favorite origi...
# 1     B000HRS7OM  ['Made with a blend of teas from Assam, Africa...
# 2     B001E5DXY0  ['We choose teas from our three favorite origi...
# 3     B004G90QE6  ['Made with a blend of teas from Assam, Africa...
# 4     B004M31ZR8  ["480 Yorkshire Tea 1 Cup Tea Bags. Why do peo...
# ...          ...                                                ...
# 7958  B01CMYK8W6  ['What happens over the course of 18 months? W...
# 7959  B01DJXXR4U  ['Four simple, natural ingredients including o...
# 7960  B01FIV3SG8  ['Tillamook Medium Cheddar Thick Sliced Cheese...
# 7961  B01FJFO2S6  ['Tillamook Country Smoker Big Dad beef sticks...
# 7962  B00BPAP4MI  ['Zaytoun', 'Statements regarding dietary supp...
#
#                                                   title  \
# 0     Taylors of Harrogate Yorkshire Gold, 40 Teabag...
# 1       Taylors of Harrogate Yorkshire Red, 160 Teabags
# 2     Taylors of Harrogate Yorkshire Gold Loose Leaf...
# 3       Taylors of Harrogate Yorkshire Red, 240 Teabags
# 4          Taylors of Harrogate Yorkshire Tea 480 Count
# ...                                                 ...
# 7958  Tillamook Extra Sharp White Cheddar Cheese Age...
# 7959  Tillamook Special Reserve Extra Sharp Cheddar ...
# 7960  Tillamook Medium Cheddar Thick Sliced Cheese 1...
# 7961  Tillamook Country Smoker Big Dad Beef Stick 20...
# 7962  Zaytoun Organic Palestinian Couscous 250 g (Pa...
#
#                                       clean_description          keywords
# 0     we choose teas from our three favorite origins...  high antioxidant
# 1     made with a blend of teas from assam africa an...               NaN
# 2     we choose teas from our three favorite origins...               NaN
# 3     made with a blend of teas from assam africa an...               NaN
# 4     yorkshire tea cup tea bags why do people love ...               NaN
# ...                                                 ...               ...
# 7958  what happens over the course of months well le...               NaN
# 7959  four simple natural ingredients including our ...      high quality
# 7960  tillamook medium cheddar thick sliced cheese o...               NaN
# 7961  tillamook country smoker big dad beef sticks a...               NaN
# 7962  zaytoun statements regarding dietary supplemen...               NaN
#
# [7963 rows x 5 columns]

# %%
integrated_data = labelled_data.merge(final_mapping, left_index=True, right_index=True, how="left").merge(supplementary_info, left_index=True, right_index=True, how="left")
integrated_data.sample(5)
# Out:
#             asin                                        description  \
# 7726  B015VKS8CA  ['', 'Take Your Favorite Fish to Another Level...
# 2871  B01BNILYSE  ['Now you can enjoy our signature Breyers Vani...
# 4027  B00514FGJU  ["Cascadian Farm Organic Sweet and Salty Chewy...
# 5753  B00E1YZUH4  ['Nutmeg is the kernel of a fruit resembling a...
# 2989  B0083FX61Y  ['All Natural, No MSG Added, Liquid Miso', 'Be...
#
#                                                   title  \
# 7726  ORGANIC Gourmet No. 19 Salmon Blend &ndash; Ju...
# 2871  Breyers Ice Cream, Natural Vanilla Snack Cups,...
# 4027  Cascadian Farm Organic Sweet and Salty Chewy G...
# 5753                Badia Baking Nutmeg Whole, 16 Ounce
# 2989                       Hikari Minute Miso, 10-Ounce
#
#                                       clean_description  \
# 7726  take your favorite fish to another level the p...
# 2871  now you can enjoy our signature breyers vanill...
# 4027  cascadian farm organic sweet and salty chewy g...
# 5753  nutmeg is the kernel of a fruit resembling an ...
# 2989  all natural no msg added liquid miso be carefu...
#
#                                                keywords  Environment  \
# 7726                                                NaN          NaN
# 2871  natural flavor, non gmo, rainforest alliance, ...     0.264085
# 4027          contain soy, natural flavor, organic food     0.760571
# 5753                                                NaN          NaN
# 2989                                                NaN          NaN
#
#         Health  Quality    Social  Allergen-free products  \
# 7726       NaN      NaN       NaN                     NaN
# 2871  0.243941      NaN  0.590057                     NaN
# 4027  0.426981      NaN       NaN               -0.173569
# 5753       NaN      NaN       NaN                     NaN
# 2989       NaN      NaN       NaN                     NaN
#
#       Gluten-free products  Lactose-free products  Vegan products  \
# 7726                   NaN                    NaN             NaN
# 2871                   NaN                    NaN             NaN
# 4027                   NaN                    NaN             NaN
# 5753                   NaN                    NaN             NaN
# 2989                   NaN                    NaN             NaN
#
#       Vegetarian products
# 7726                  NaN
# 2871                  NaN
# 4027                  NaN
# 5753                  NaN
# 2989                  NaN

# %%
sample_index = 7544
print(f"Sample Index: {sample_index}")
print(f"Product details for the considered sample: \nTitle: {labelled_data.iloc[sample_index]['title']}")
print(f"Description: {labelled_data.iloc[sample_index]['clean_description']}")
print(f"Keyword Identified: {keyword_extractor.get_vocab()[product_tfidf[sample_index].indices]}")
keyword_mapper.ontology_data.iloc[keyword_mapper.mapping[keyword_mapper.mapping["product_idx"]==sample_index]["onto_idx"]]
# Out:
# Sample Index: 7544
# Product details for the considered sample:
# Title: Gourmet Chocolate No Bake Cookies 24 Hand-Made, Hand-Wrapped Gift Boxed, Made to Order, Fresh, FREE Expedited Shipping, Perfect for Holidays, Gifts, Showers, Special Occasions, No Occasion (24 Non Gift Boxed Cookies)
# Description: i have been making these chocolate no bake cookies for years after raving over them for years our family and friends finally convinced us to make them available to the public so after much consideration we decided to go for it we will make your cookies fresh and carefully hand wrap each one each cookie is hand dipped into our molds which gives them the unique shape we use only quality ingredients including real butter raw sugar real pure vanilla for those with food allergies please be aware that there are both dairy and peanut product in our cookies there are no preservatives or funky additives in our cookies they are made fresh to enjoy now they are rich and smooth and oh so chocolaty it truly is difficult to eat just one these cookies are perfect for all occasions give them as gifts for the holidays birthdays showers house warmings the list goes on you bring these cookies to the party and you are an instant hero you can order from us with complete confidence we have been selling online since and we pride ourselves in giving amazon like customer service if you ain t happy we ain t happy we appreciate your business ya ll be blessed o sherry sherry s gourmet cookies p s we appreciate positive feedback if you love our cookies o cocoa raw sugar peanut butter oats milk vanilla butter statements regarding dietary supplements have not been evaluated by the fda and are not intended to diagnose treat cure or prevent any disease or health condition
# Keyword Identified: ['dairy product' 'no additive' 'no preservative' 'peanut product']
#                                                    tag  \
# idx
# 26                             allergen peanut product
# 25                             allergen peanut product
# 245                                    no preservative
# 243                            no milk beside additive
# 242                            no milk beside additive
# 241                            no milk beside additive
# 236                            no meat beside additive
# 235                            no meat beside additive
# 234                            no meat beside additive
# 232                          no gluten beside additive
# 226                             no egg beside additive
# 225                             no egg beside additive
# 216                             no artificial additive
# 17   allergen milk of mammal and dairy product incl...
#
#                                             preference preference category  \
# idx
# 26                               High-protein products              Health
# 25                              Allergen-free products              Health
# 245                     Products without preservatives              Health
# 243                                     Vegan products              Health
# 242  Products from companies that support animal ri...              Social
# 241                              Lactose-free products              Health
# 236                                Vegetarian products              Health
# 235                                     Vegan products              Health
# 234  Products from companies that support animal ri...              Social
# 232                               Gluten-free products              Health
# 226                                     Vegan products              Health
# 225  Products from companies that support animal ri...              Social
# 216  Products without artificial colours or flavor ...              Health
# 17                              Allergen-free products              Health
#
#      association  conditional
# idx
# 26             1        False
# 25            -1         True
# 245            1        False
# 243            1         True
# 242            1        False
# 241            1         True
# 236            1         True
# 235            1         True
# 234            1        False
# 232            1         True
# 226            1         True
# 225            1        False
# 216            1        False
# 17            -1         True

# %%
sample_index = 479
print(f"Sample Index: {sample_index}")
print(f"Product details for the considered sample: \nTitle: {labelled_data.iloc[sample_index]['title']}")
print(f"Description: {labelled_data.iloc[sample_index]['clean_description']}")
print(f"Keyword Identified: {keyword_extractor.get_vocab()[product_tfidf[sample_index].indices]}")
keyword_mapper.ontology_data.iloc[keyword_mapper.mapping[keyword_mapper.mapping["product_idx"]==sample_index]["onto_idx"]]
# Out:
# Sample Index: 479
# Product details for the considered sample:
# Title: Simply Organic Red Pepper Crushed Certified Organic, 0.42-Ounce (Pack of 6)
# Description: simply organic red pepper crushed comes in ounce containers a must for mexican and african cooking chili flakes will liven up any dish use sparingly in marinara and pizza sauces and on grilled vegetables and meats chilies can be irritating to the eyes and skin so handle with caution all information is provided on a per serving basis for the unprepared product frontier handles milk and egg products and does not test finished goods for the presence of allergens unless otherwise specified as certified organic crushed red pepper statements regarding dietary supplements have not been evaluated by the fda and are not intended to diagnose treat cure or prevent any disease or health condition
# Keyword Identified: ['certified organic' 'egg product' 'milk product' 'not test']
#                                                    tag  \
# idx
# 192                  isnt proven not to test on animal
# 17   allergen milk of mammal and dairy product incl...
# 6                      allergen egg of poultry product
# 49                                   certified organic
# 48                                   certified organic
# 47                                   certified organic
#
#                                             preference preference category  \
# idx
# 192  Products from companies that support animal ri...              Social
# 17                              Allergen-free products              Health
# 6                               Allergen-free products              Health
# 49                         Sustainably farmed products         Environment
# 48                                     Organic Product              Health
# 47   Products evaluated with auditing processes tha...              Social
#
#      association  conditional
# idx
# 192           -1        False
# 17            -1         True
# 6             -1         True
# 49             1        False
# 48             1        False
# 47             1        False

# %%
print(f"Final Shape of the Data = {integrated_data.shape}")
# Out:
# Final Shape of the Data = (7963, 14)
